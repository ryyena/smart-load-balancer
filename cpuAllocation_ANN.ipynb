# %% [markdown]
# <a href="https://colab.research.google.com/github/ryyena/smart-load-balancer/blob/main/cpuAllocation_ANN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Importing libraries**

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import ast
import sklearn
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.multioutput import MultiOutputRegressor
from sklearn.preprocessing import LabelEncoder
from xgboost import XGBRegressor
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, mean_squared_error, precision_score, recall_score, f1_score
from sklearn.preprocessing import StandardScaler, LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# **Importing dataset**

# %%
dataset = pd.read_csv('/content/borg_traces_data.csv', engine='python')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dataset.head()
# Out:
#    Unnamed: 0          time  instance_events_type  collection_id  \
# 0           0  0.000000e+00                     2   9.459124e+10
# 1           1  2.517310e+12                     2   2.606980e+11
# 2           2  1.956840e+11                     6   2.762270e+11
# 3           3  0.000000e+00                     2   1.050739e+10
# 4           4  1.810630e+12                     3   2.591162e+10
#
#    scheduling_class  collection_type  priority  alloc_collection_id  \
# 0                 3                1       200         0.000000e+00
# 1                 2                0       360         2.214950e+11
# 2                 2                0       103         0.000000e+00
# 3                 3                0       200         0.000000e+00
# 4                 2                0         0         0.000000e+00
#
#    instance_index    machine_id  \
# 0             144  1.688460e+11
# 1             335  8.551509e+07
# 2             376  1.693220e+11
# 3            1977  1.782950e+11
# 4            3907  2.313650e+11
#
#                                     resource_request constraint  \
# 0  {'cpus': 0.020660400390625, 'memory': 0.014434...         []
# 1  {'cpus': 0.00724029541015625, 'memory': 0.0013...         []
# 2  {'cpus': 0.048583984375, 'memory': 0.004165649...         []
# 3  {'cpus': 0.0704345703125, 'memory': 0.04162597...         []
# 4  {'cpus': 0.00244903564453125, 'memory': 0.0002...         []
#
#    collections_events_type                                          user  \
# 0                        2  fn8Ve4Tdl/FVVvwXFGIKe4+Wo4zLjUL/557qdFVYu5M=
# 1                        2  DrrEIEWkWuW7RrZwpHLCN0k0A2J0usJeyt3wtqzZ7Kk=
# 2                        6  /ivQBmewiFcXfGJdCUsEKx47NiRE29Tjiq3gw+zR2Cg=
# 3                        2  8qRmTJas/6XEBaA0l4Wt1+/qSLgc6p7u7JzoMSuT/M8=
# 4                        3  +cz+wEXttqDjld+YWLmrgqExjdqiHMZ2WZODThyR9jE=
#
#                                 collection_name  \
# 0  Hzsv/gF8CPQXdqpsfovDTC1TJNyphDxPu7vaTeNxA74=
# 1  hDGffcrF/rhQQEG8Uns/RMUK7R15DXjFnRasoKFhefI=
# 2  kk6+maA6fvAdJ+VTU8AcpzQPTyVrx+ySt0MXRAyO8FU=
# 3  fypwFjdqaQPSxCfeqVPCBAvFcnntmkRpQxwQ/vJsCxU=
# 4  WS2kraTQdfsFtOIepw9SIo7ETi2ag8uwy7gt2MrpIe0=
#
#                         collection_logical_name start_after_collection_ids  \
# 0  YCuhYrnORLiUh9WGL5q5tkBevfwtucSnFr2qPZh6Kes=                         []
# 1  wcRcAMuop2OqH9EW4feH919tadFec5a11ply0hcS/C8=                         []
# 2  zCA2dl2PDptd82Hob906gE82JHzx0SbqA4mZurqZdmY=                         []
# 3  uNjMQD1+DL9IgCFckx8lHOsCbyvLgKmZCmRjiyWZNhk=                         []
# 4  VJ0ExwthLLpbqbyOA77EoNypzEiPYg3mECxUve0GCnY=                         []
#
#    vertical_scaling  scheduler    start_time      end_time  \
# 0               1.0        0.0  2.748000e+11  2.751000e+11
# 1               2.0        0.0  1.800710e+12  1.800710e+12
# 2               2.0        1.0  8.130000e+10  8.160000e+10
# 3               2.0        0.0  1.075500e+12  1.075800e+12
# 4               3.0        0.0  1.565320e+12  1.565320e+12
#
#                                        average_usage  \
# 0  {'cpus': 0.00466156005859375, 'memory': 0.0059...
# 1       {'cpus': 0.0, 'memory': 9.5367431640625e-07}
# 2  {'cpus': 0.024200439453125, 'memory': 0.002788...
# 3  {'cpus': 0.047607421875, 'memory': 0.034423828...
# 4  {'cpus': 0.000270843505859375, 'memory': 7.629...
#
#                                        maximum_usage  \
# 0  {'cpus': 0.01190185546875, 'memory': 0.0059356...
# 1       {'cpus': 0.0, 'memory': 9.5367431640625e-07}
# 2  {'cpus': 0.06005859375, 'memory': 0.0028457641...
# 3   {'cpus': 0.13330078125, 'memory': 0.03466796875}
# 4  {'cpus': 0.00041484832763671875, 'memory': 7.6...
#
#                                random_sample_usage  assigned_memory  \
# 0     {'cpus': 0.0043487548828125, 'memory': None}         0.014435
# 1                    {'cpus': 0.0, 'memory': None}         0.000000
# 2      {'cpus': 0.026458740234375, 'memory': None}         0.010422
# 3       {'cpus': 0.05084228515625, 'memory': None}         0.041626
# 4  {'cpus': 0.0003414154052734375, 'memory': None}         0.000272
#
#    page_cache_memory  cycles_per_instruction  memory_accesses_per_instruction  \
# 0           0.000415                     NaN                              NaN
# 1           0.000000                     NaN                              NaN
# 2           0.000235                0.939919                         0.001318
# 3           0.000225                1.359102                         0.007643
# 4           0.000010                     NaN                              NaN
#
#    sample_rate                             cpu_usage_distribution  \
# 0          1.0  [0.00314331 0.00381088 0.00401306 0.00415039 0...
# 1          1.0  [1.23977661e-05 1.23977661e-05 1.23977661e-05 ...
# 2          1.0  [0.01344299 0.01809692 0.0201416  0.02246094 0...
# 3          1.0  [0.03704834 0.04125977 0.04290771 0.04425049 0...
# 4          1.0  [0.         0.         0.         0.         0...
#
#                          tail_cpu_usage_distribution  cluster     event  \
# 0  [0.00535583 0.00541687 0.00548553 0.00554657 0...        7      FAIL
# 1  [1.23977661e-05 1.23977661e-05 1.23977661e-05 ...        7      FAIL
# 2  [0.02902222 0.02929688 0.0295105  0.0296936  0...        7  SCHEDULE
# 3  [0.05535889 0.05584717 0.05633545 0.05718994 0...        8      FAIL
# 4  [0.00041485 0.00041485 0.00041485 0.00041485 0...        2    FINISH
#
#    failed
# 0       1
# 1       1
# 2       0
# 3       1
# 4       0

# %%
dataset.shape
# Out:
# (405894, 34)

# %% [markdown]
# **Data preprocessing**

# %% [markdown]
# **Feature engineering**

# %%
dataset['duration'] = dataset['end_time'] - dataset['start_time']

# %%
# Convert strings to actual dictionaries
dataset['resource_request'] = dataset['resource_request'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

# Now extract the values
dataset['cpu_resource_request'] = dataset['resource_request'].apply(
    lambda x: x.get('cpus') if isinstance(x, dict) else None
)

dataset['memory_resource_request'] = dataset['resource_request'].apply(
    lambda x: x.get('memory') if isinstance(x, dict) else None
)

# %%
# Convert strings to actual dictionaries
dataset['average_usage'] = dataset['average_usage'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

# Now extract the values
dataset['cpu_average_usage'] = dataset['average_usage'].apply(
    lambda x: x.get('cpus') if isinstance(x, dict) else None
)

dataset['memory_average_usage'] = dataset['average_usage'].apply(
    lambda x: x.get('memory') if isinstance(x, dict) else None
)

# %%
pd.set_option('display.max_columns', None)
dataset.head()
# Out:
#    Unnamed: 0          time  instance_events_type  collection_id  \
# 0           0  0.000000e+00                     2   9.459124e+10
# 1           1  2.517310e+12                     2   2.606980e+11
# 2           2  1.956840e+11                     6   2.762270e+11
# 3           3  0.000000e+00                     2   1.050739e+10
# 4           4  1.810630e+12                     3   2.591162e+10
#
#    scheduling_class  collection_type  priority  alloc_collection_id  \
# 0                 3                1       200         0.000000e+00
# 1                 2                0       360         2.214950e+11
# 2                 2                0       103         0.000000e+00
# 3                 3                0       200         0.000000e+00
# 4                 2                0         0         0.000000e+00
#
#    instance_index    machine_id  \
# 0             144  1.688460e+11
# 1             335  8.551509e+07
# 2             376  1.693220e+11
# 3            1977  1.782950e+11
# 4            3907  2.313650e+11
#
#                                     resource_request constraint  \
# 0  {'cpus': 0.020660400390625, 'memory': 0.014434...         []
# 1  {'cpus': 0.00724029541015625, 'memory': 0.0013...         []
# 2  {'cpus': 0.048583984375, 'memory': 0.004165649...         []
# 3  {'cpus': 0.0704345703125, 'memory': 0.04162597...         []
# 4  {'cpus': 0.00244903564453125, 'memory': 0.0002...         []
#
#    collections_events_type                                          user  \
# 0                        2  fn8Ve4Tdl/FVVvwXFGIKe4+Wo4zLjUL/557qdFVYu5M=
# 1                        2  DrrEIEWkWuW7RrZwpHLCN0k0A2J0usJeyt3wtqzZ7Kk=
# 2                        6  /ivQBmewiFcXfGJdCUsEKx47NiRE29Tjiq3gw+zR2Cg=
# 3                        2  8qRmTJas/6XEBaA0l4Wt1+/qSLgc6p7u7JzoMSuT/M8=
# 4                        3  +cz+wEXttqDjld+YWLmrgqExjdqiHMZ2WZODThyR9jE=
#
#                                 collection_name  \
# 0  Hzsv/gF8CPQXdqpsfovDTC1TJNyphDxPu7vaTeNxA74=
# 1  hDGffcrF/rhQQEG8Uns/RMUK7R15DXjFnRasoKFhefI=
# 2  kk6+maA6fvAdJ+VTU8AcpzQPTyVrx+ySt0MXRAyO8FU=
# 3  fypwFjdqaQPSxCfeqVPCBAvFcnntmkRpQxwQ/vJsCxU=
# 4  WS2kraTQdfsFtOIepw9SIo7ETi2ag8uwy7gt2MrpIe0=
#
#                         collection_logical_name start_after_collection_ids  \
# 0  YCuhYrnORLiUh9WGL5q5tkBevfwtucSnFr2qPZh6Kes=                         []
# 1  wcRcAMuop2OqH9EW4feH919tadFec5a11ply0hcS/C8=                         []
# 2  zCA2dl2PDptd82Hob906gE82JHzx0SbqA4mZurqZdmY=                         []
# 3  uNjMQD1+DL9IgCFckx8lHOsCbyvLgKmZCmRjiyWZNhk=                         []
# 4  VJ0ExwthLLpbqbyOA77EoNypzEiPYg3mECxUve0GCnY=                         []
#
#    vertical_scaling  scheduler    start_time      end_time  \
# 0               1.0        0.0  2.748000e+11  2.751000e+11
# 1               2.0        0.0  1.800710e+12  1.800710e+12
# 2               2.0        1.0  8.130000e+10  8.160000e+10
# 3               2.0        0.0  1.075500e+12  1.075800e+12
# 4               3.0        0.0  1.565320e+12  1.565320e+12
#
#                                        average_usage  \
# 0  {'cpus': 0.00466156005859375, 'memory': 0.0059...
# 1       {'cpus': 0.0, 'memory': 9.5367431640625e-07}
# 2  {'cpus': 0.024200439453125, 'memory': 0.002788...
# 3  {'cpus': 0.047607421875, 'memory': 0.034423828...
# 4  {'cpus': 0.000270843505859375, 'memory': 7.629...
#
#                                        maximum_usage  \
# 0  {'cpus': 0.01190185546875, 'memory': 0.0059356...
# 1       {'cpus': 0.0, 'memory': 9.5367431640625e-07}
# 2  {'cpus': 0.06005859375, 'memory': 0.0028457641...
# 3   {'cpus': 0.13330078125, 'memory': 0.03466796875}
# 4  {'cpus': 0.00041484832763671875, 'memory': 7.6...
#
#                                random_sample_usage  assigned_memory  \
# 0     {'cpus': 0.0043487548828125, 'memory': None}         0.014435
# 1                    {'cpus': 0.0, 'memory': None}         0.000000
# 2      {'cpus': 0.026458740234375, 'memory': None}         0.010422
# 3       {'cpus': 0.05084228515625, 'memory': None}         0.041626
# 4  {'cpus': 0.0003414154052734375, 'memory': None}         0.000272
#
#    page_cache_memory  cycles_per_instruction  memory_accesses_per_instruction  \
# 0           0.000415                     NaN                              NaN
# 1           0.000000                     NaN                              NaN
# 2           0.000235                0.939919                         0.001318
# 3           0.000225                1.359102                         0.007643
# 4           0.000010                     NaN                              NaN
#
#    sample_rate                             cpu_usage_distribution  \
# 0          1.0  [0.00314331 0.00381088 0.00401306 0.00415039 0...
# 1          1.0  [1.23977661e-05 1.23977661e-05 1.23977661e-05 ...
# 2          1.0  [0.01344299 0.01809692 0.0201416  0.02246094 0...
# 3          1.0  [0.03704834 0.04125977 0.04290771 0.04425049 0...
# 4          1.0  [0.         0.         0.         0.         0...
#
#                          tail_cpu_usage_distribution  cluster     event  \
# 0  [0.00535583 0.00541687 0.00548553 0.00554657 0...        7      FAIL
# 1  [1.23977661e-05 1.23977661e-05 1.23977661e-05 ...        7      FAIL
# 2  [0.02902222 0.02929688 0.0295105  0.0296936  0...        7  SCHEDULE
# 3  [0.05535889 0.05584717 0.05633545 0.05718994 0...        8      FAIL
# 4  [0.00041485 0.00041485 0.00041485 0.00041485 0...        2    FINISH
#
#    failed     duration  cpu_resource_request  memory_resource_request  \
# 0       1  300000000.0              0.020660                 0.014435
# 1       1          0.0              0.007240                 0.001303
# 2       0  300000000.0              0.048584                 0.004166
# 3       1  300000000.0              0.070435                 0.041626
# 4       0          0.0              0.002449                 0.000232
#
#    cpu_average_usage  memory_average_usage
# 0           0.004662          5.920410e-03
# 1           0.000000          9.536743e-07
# 2           0.024200          2.788544e-03
# 3           0.047607          3.442383e-02
# 4           0.000271          7.629395e-05

# %%
dataset.shape
# Out:
# (405894, 39)

# %%
dataset.head()
dataset.head()
dataset = dataset.drop([ 'collection_id','constraint','user','collection_name', 'resource_request','average_usage','maximum_usage', 'alloc_collection_id', 'instance_index', 'start_time', 'end_time', 'start_after_collection_ids', 'collection_logical_name', 'time', 'sample_rate', 'random_sample_usage','cpu_usage_distribution', 'tail_cpu_usage_distribution', 'machine_id', 'assigned_memory', 'page_cache_memory', 'cycles_per_instruction', 'memory_accesses_per_instruction'], axis=1)

# %%
dataset.shape
# Out:
# (405894, 16)

# %%
dataset.head()
# Out:
#    Unnamed: 0  instance_events_type  scheduling_class  collection_type  \
# 0           0                     2                 3                1
# 1           1                     2                 2                0
# 2           2                     6                 2                0
# 3           3                     2                 3                0
# 4           4                     3                 2                0
#
#    priority  collections_events_type  vertical_scaling  scheduler  cluster  \
# 0       200                        2               1.0        0.0        7
# 1       360                        2               2.0        0.0        7
# 2       103                        6               2.0        1.0        7
# 3       200                        2               2.0        0.0        8
# 4         0                        3               3.0        0.0        2
#
#       event  failed     duration  cpu_resource_request  \
# 0      FAIL       1  300000000.0              0.020660
# 1      FAIL       1          0.0              0.007240
# 2  SCHEDULE       0  300000000.0              0.048584
# 3      FAIL       1  300000000.0              0.070435
# 4    FINISH       0          0.0              0.002449
#
#    memory_resource_request  cpu_average_usage  memory_average_usage
# 0                 0.014435           0.004662          5.920410e-03
# 1                 0.001303           0.000000          9.536743e-07
# 2                 0.004166           0.024200          2.788544e-03
# 3                 0.041626           0.047607          3.442383e-02
# 4                 0.000232           0.000271          7.629395e-05

# %%
dataset = dataset.drop(dataset.columns[[0]], axis=1)

# %% [markdown]
# **Handling missing values**

# %%
dataset.isnull().sum()
# Out:
# instance_events_type         0
# scheduling_class             0
# collection_type              0
# priority                     0
# collections_events_type      0
# vertical_scaling           959
# scheduler                  959
# cluster                      0
# event                        0
# failed                       0
# duration                     0
# cpu_resource_request       774
# memory_resource_request    774
# cpu_average_usage            0
# memory_average_usage         0
# dtype: int64

# %%
# Impute missing values with the most frequent value (mode) for each column
dataset['scheduler'].fillna(dataset['scheduler'].mode()[0], inplace=True)
dataset['vertical_scaling'].fillna(dataset['vertical_scaling'].mode()[0], inplace=True)
# Out:
# /tmp/ipython-input-1672505734.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['scheduler'].fillna(dataset['scheduler'].mode()[0], inplace=True)
# /tmp/ipython-input-1672505734.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['vertical_scaling'].fillna(dataset['vertical_scaling'].mode()[0], inplace=True)

# %%
# Impute using median for skewed distributions
dataset['cpu_resource_request'].fillna(dataset['cpu_resource_request'].median(), inplace=True)
dataset['memory_resource_request'].fillna(dataset['memory_resource_request'].median(), inplace=True)
# Out:
# /tmp/ipython-input-3128009393.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['cpu_resource_request'].fillna(dataset['cpu_resource_request'].median(), inplace=True)
# /tmp/ipython-input-3128009393.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['memory_resource_request'].fillna(dataset['memory_resource_request'].median(), inplace=True)

# %%
dataset.isnull().sum()
# Out:
# instance_events_type       0
# scheduling_class           0
# collection_type            0
# priority                   0
# collections_events_type    0
# vertical_scaling           0
# scheduler                  0
# cluster                    0
# event                      0
# failed                     0
# duration                   0
# cpu_resource_request       0
# memory_resource_request    0
# cpu_average_usage          0
# memory_average_usage       0
# dtype: int64

# %% [markdown]
# **Encoding categorical data**

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
dataset['event'] = le.fit_transform(dataset['event'])

# %%
dataset['event']
# Out:
# 0         2
# 1         2
# 2         7
# 3         2
# 4         3
#          ..
# 405889    2
# 405890    0
# 405891    3
# 405892    2
# 405893    5
# Name: event, Length: 405894, dtype: int64

# %% [markdown]
# **Handling skewed data and converting it into categories using binning**

# %%
dataset['cpu_usage_log'] = np.log1p(dataset['cpu_average_usage'])
dataset['memory_usage_log'] = np.log1p(dataset['memory_average_usage'])

# %%
labels = ['Very Very Low', 'Very Low', 'Low', 'Medium', 'High', 'Very High', 'Very Very High']

# Create categorical column for cpu_usage_log
dataset['cpu_usage_log_categorical'] = pd.qcut(
    dataset['cpu_usage_log'],  # transformed numeric column
    q=7,                       # number of bins
    labels=labels
)

# Create categorical column for memory_usage_log
dataset['memory_usage_log_categorical'] = pd.qcut(
    dataset['memory_usage_log'],  # transformed numeric column
    q=7,                       # number of bins
    labels=labels
)

# %%
dataset['cpu_usage_log_categorical'].value_counts()
# Out:
# cpu_usage_log_categorical
# Very Low          62129
# Medium            58066
# Very Very Low     58054
# Very High         57910
# Very Very High    57780
# High              56226
# Low               55729
# Name: count, dtype: int64

# %%
dataset['memory_usage_log_categorical'].value_counts()
# Out:
# memory_usage_log_categorical
# Low               58690
# Very High         58157
# Very Very Low     58147
# High              57987
# Very Low          57899
# Very Very High    57678
# Medium            57336
# Name: count, dtype: int64

# %%
dataset.head()
# Out:
#    instance_events_type  scheduling_class  collection_type  priority  \
# 0                     2                 3                1       200
# 1                     2                 2                0       360
# 2                     6                 2                0       103
# 3                     2                 3                0       200
# 4                     3                 2                0         0
#
#    collections_events_type  vertical_scaling  scheduler  cluster  event  \
# 0                        2               1.0        0.0        7      2
# 1                        2               2.0        0.0        7      2
# 2                        6               2.0        1.0        7      7
# 3                        2               2.0        0.0        8      2
# 4                        3               3.0        0.0        2      3
#
#    failed     duration  cpu_resource_request  memory_resource_request  \
# 0       1  300000000.0              0.020660                 0.014435
# 1       1          0.0              0.007240                 0.001303
# 2       0  300000000.0              0.048584                 0.004166
# 3       1  300000000.0              0.070435                 0.041626
# 4       0          0.0              0.002449                 0.000232
#
#    cpu_average_usage  memory_average_usage  cpu_usage_log  memory_usage_log  \
# 0           0.004662          5.920410e-03       0.004651      5.902953e-03
# 1           0.000000          9.536743e-07       0.000000      9.536739e-07
# 2           0.024200          2.788544e-03       0.023912      2.784663e-03
# 3           0.047607          3.442383e-02       0.046509      3.384458e-02
# 4           0.000271          7.629395e-05       0.000271      7.629104e-05
#
#   cpu_usage_log_categorical memory_usage_log_categorical
# 0                      High                    Very High
# 1             Very Very Low                Very Very Low
# 2            Very Very High                         High
# 3            Very Very High               Very Very High
# 4                       Low                Very Very Low

# %%
dataset = dataset.drop(['cpu_average_usage', 'cpu_usage_log', 'memory_average_usage', 'memory_usage_log'], axis=1)

# %% [markdown]
# **Defining target and feature variables for load balancing**

# %%
X = dataset.drop(columns=['cpu_usage_log_categorical','memory_usage_log_categorical'])
y = dataset['cpu_usage_log_categorical']
y_no = dataset['memory_usage_log_categorical']

# %% [markdown]
# **Encoding target variable**

# %%
# Step 3.1: Label encode (text → integer codes)
encoder = LabelEncoder()
y_encoded = encoder.fit_transform(y)

# Step 3.2: One-hot encode (integer codes → one-hot matrix)
y_onehot = to_categorical(y_encoded)

# %% [markdown]
# **Splitting into train and test sets**

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y_onehot, test_size=0.2, random_state=42, stratify=y_onehot
)

# %% [markdown]
# **ANN model**

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
dataset.shape
# Out:
# (405894, 15)

# %%
model = Sequential()
model.add(Dense(128, activation='relu', input_shape=(13,)))
model.add(Dropout(0.2))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(32, activation='relu'))
model.add(Dense(7, activation='softmax'))  # 7 output neurons
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
from tensorflow.keras.optimizers import Adam
optimizer = Adam(learning_rate=0.003)

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# Define early stopping before calling fit
early = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True,
    verbose=1
)

# %%
lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,  # reduce LR by half
    patience=3,  # wait 3 epochs before reducing LR
    verbose=1
)

# %% [markdown]
# **Training**

# %%
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=100,
    batch_size=256,
    callbacks=[early, lr_scheduler],  # Make sure it's inside a list
    verbose=1
)
# Out:
# Epoch 1/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.5244 - loss: 1.2739 - val_accuracy: 0.7117 - val_loss: 0.7846 - learning_rate: 0.0010
# Epoch 2/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.6824 - loss: 0.8645 - val_accuracy: 0.7592 - val_loss: 0.6636 - learning_rate: 0.0010
# Epoch 3/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.7186 - loss: 0.7666 - val_accuracy: 0.7758 - val_loss: 0.6045 - learning_rate: 0.0010
# Epoch 4/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.7372 - loss: 0.7165 - val_accuracy: 0.8043 - val_loss: 0.5596 - learning_rate: 0.0010
# Epoch 5/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.7540 - loss: 0.6738 - val_accuracy: 0.8145 - val_loss: 0.5299 - learning_rate: 0.0010
# Epoch 6/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.7637 - loss: 0.6499 - val_accuracy: 0.8202 - val_loss: 0.5102 - learning_rate: 0.0010
# Epoch 7/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.7727 - loss: 0.6246 - val_accuracy: 0.8333 - val_loss: 0.4867 - learning_rate: 0.0010
# Epoch 8/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.7793 - loss: 0.6074 - val_accuracy: 0.8351 - val_loss: 0.4709 - learning_rate: 0.0010
# Epoch 9/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.7845 - loss: 0.5924 - val_accuracy: 0.8402 - val_loss: 0.4610 - learning_rate: 0.0010
# Epoch 10/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.7870 - loss: 0.5815 - val_accuracy: 0.8410 - val_loss: 0.4519 - learning_rate: 0.0010
# Epoch 11/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.7921 - loss: 0.5705 - val_accuracy: 0.8479 - val_loss: 0.4400 - learning_rate: 0.0010
# Epoch 12/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.7949 - loss: 0.5636 - val_accuracy: 0.8463 - val_loss: 0.4342 - learning_rate: 0.0010
# Epoch 13/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.7984 - loss: 0.5554 - val_accuracy: 0.8464 - val_loss: 0.4298 - learning_rate: 0.0010
# Epoch 14/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.8010 - loss: 0.5448 - val_accuracy: 0.8509 - val_loss: 0.4230 - learning_rate: 0.0010
# Epoch 15/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.8019 - loss: 0.5442 - val_accuracy: 0.8566 - val_loss: 0.4169 - learning_rate: 0.0010
# Epoch 16/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.8025 - loss: 0.5399 - val_accuracy: 0.8537 - val_loss: 0.4119 - learning_rate: 0.0010
# Epoch 17/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.8079 - loss: 0.5279 - val_accuracy: 0.8538 - val_loss: 0.4086 - learning_rate: 0.0010
# Epoch 18/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8082 - loss: 0.5243 - val_accuracy: 0.8565 - val_loss: 0.4036 - learning_rate: 0.0010
# Epoch 19/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - accuracy: 0.8106 - loss: 0.5220 - val_accuracy: 0.8591 - val_loss: 0.3982 - learning_rate: 0.0010
# Epoch 20/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8113 - loss: 0.5187 - val_accuracy: 0.8576 - val_loss: 0.3954 - learning_rate: 0.0010
# Epoch 21/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.8138 - loss: 0.5134 - val_accuracy: 0.8614 - val_loss: 0.3935 - learning_rate: 0.0010
# Epoch 22/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.8129 - loss: 0.5121 - val_accuracy: 0.8630 - val_loss: 0.3890 - learning_rate: 0.0010
# Epoch 23/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.8134 - loss: 0.5109 - val_accuracy: 0.8616 - val_loss: 0.3861 - learning_rate: 0.0010
# Epoch 24/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8153 - loss: 0.5056 - val_accuracy: 0.8636 - val_loss: 0.3828 - learning_rate: 0.0010
# Epoch 25/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.8178 - loss: 0.5031 - val_accuracy: 0.8647 - val_loss: 0.3850 - learning_rate: 0.0010
# Epoch 26/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.8175 - loss: 0.5001 - val_accuracy: 0.8651 - val_loss: 0.3825 - learning_rate: 0.0010
# Epoch 27/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.8164 - loss: 0.5013 - val_accuracy: 0.8672 - val_loss: 0.3778 - learning_rate: 0.0010
# Epoch 28/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - accuracy: 0.8187 - loss: 0.4971 - val_accuracy: 0.8652 - val_loss: 0.3772 - learning_rate: 0.0010
# Epoch 29/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.8196 - loss: 0.4940 - val_accuracy: 0.8671 - val_loss: 0.3757 - learning_rate: 0.0010
# Epoch 30/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - accuracy: 0.8194 - loss: 0.4934 - val_accuracy: 0.8642 - val_loss: 0.3776 - learning_rate: 0.0010
# Epoch 31/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.8213 - loss: 0.4911 - val_accuracy: 0.8662 - val_loss: 0.3711 - learning_rate: 0.0010
# Epoch 32/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.8213 - loss: 0.4909 - val_accuracy: 0.8655 - val_loss: 0.3736 - learning_rate: 0.0010
# Epoch 33/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - accuracy: 0.8209 - loss: 0.4889 - val_accuracy: 0.8687 - val_loss: 0.3709 - learning_rate: 0.0010
# Epoch 34/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - accuracy: 0.8216 - loss: 0.4870 - val_accuracy: 0.8662 - val_loss: 0.3688 - learning_rate: 0.0010
# Epoch 35/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.8235 - loss: 0.4829 - val_accuracy: 0.8673 - val_loss: 0.3680 - learning_rate: 0.0010
# Epoch 36/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - accuracy: 0.8222 - loss: 0.4839 - val_accuracy: 0.8650 - val_loss: 0.3691 - learning_rate: 0.0010
# Epoch 37/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.8242 - loss: 0.4806 - val_accuracy: 0.8677 - val_loss: 0.3645 - learning_rate: 0.0010
# Epoch 38/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.8238 - loss: 0.4811 - val_accuracy: 0.8671 - val_loss: 0.3622 - learning_rate: 0.0010
# Epoch 39/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.8231 - loss: 0.4818 - val_accuracy: 0.8686 - val_loss: 0.3647 - learning_rate: 0.0010
# Epoch 40/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 12s 8ms/step - accuracy: 0.8243 - loss: 0.4780 - val_accuracy: 0.8711 - val_loss: 0.3613 - learning_rate: 0.0010
# Epoch 41/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.8249 - loss: 0.4800 - val_accuracy: 0.8681 - val_loss: 0.3634 - learning_rate: 0.0010
# Epoch 42/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.8247 - loss: 0.4793 - val_accuracy: 0.8713 - val_loss: 0.3608 - learning_rate: 0.0010
# Epoch 43/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.8270 - loss: 0.4735 - val_accuracy: 0.8695 - val_loss: 0.3594 - learning_rate: 0.0010
# Epoch 44/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.8263 - loss: 0.4729 - val_accuracy: 0.8716 - val_loss: 0.3585 - learning_rate: 0.0010
# Epoch 45/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.8275 - loss: 0.4727 - val_accuracy: 0.8710 - val_loss: 0.3585 - learning_rate: 0.0010
# Epoch 46/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.8258 - loss: 0.4732 - val_accuracy: 0.8675 - val_loss: 0.3614 - learning_rate: 0.0010
# Epoch 47/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - accuracy: 0.8265 - loss: 0.4700 - val_accuracy: 0.8705 - val_loss: 0.3574 - learning_rate: 0.0010
# Epoch 48/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.8274 - loss: 0.4718 - val_accuracy: 0.8683 - val_loss: 0.3586 - learning_rate: 0.0010
# Epoch 49/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - accuracy: 0.8270 - loss: 0.4689 - val_accuracy: 0.8687 - val_loss: 0.3578 - learning_rate: 0.0010
# Epoch 50/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.8290 - loss: 0.4685 - val_accuracy: 0.8702 - val_loss: 0.3531 - learning_rate: 0.0010
# Epoch 51/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - accuracy: 0.8288 - loss: 0.4669 - val_accuracy: 0.8735 - val_loss: 0.3545 - learning_rate: 0.0010
# Epoch 52/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - accuracy: 0.8282 - loss: 0.4676 - val_accuracy: 0.8720 - val_loss: 0.3548 - learning_rate: 0.0010
# Epoch 53/100
# 1263/1269 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8283 - loss: 0.4690
# Epoch 53: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.8283 - loss: 0.4690 - val_accuracy: 0.8708 - val_loss: 0.3548 - learning_rate: 0.0010
# Epoch 54/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - accuracy: 0.8330 - loss: 0.4569 - val_accuracy: 0.8755 - val_loss: 0.3454 - learning_rate: 5.0000e-04
# Epoch 55/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - accuracy: 0.8326 - loss: 0.4533 - val_accuracy: 0.8736 - val_loss: 0.3457 - learning_rate: 5.0000e-04
# Epoch 56/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - accuracy: 0.8338 - loss: 0.4528 - val_accuracy: 0.8747 - val_loss: 0.3452 - learning_rate: 5.0000e-04
# Epoch 57/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - accuracy: 0.8346 - loss: 0.4506 - val_accuracy: 0.8762 - val_loss: 0.3442 - learning_rate: 5.0000e-04
# Epoch 58/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - accuracy: 0.8333 - loss: 0.4512 - val_accuracy: 0.8756 - val_loss: 0.3419 - learning_rate: 5.0000e-04
# Epoch 59/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.8340 - loss: 0.4522 - val_accuracy: 0.8758 - val_loss: 0.3420 - learning_rate: 5.0000e-04
# Epoch 60/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.8346 - loss: 0.4490 - val_accuracy: 0.8765 - val_loss: 0.3412 - learning_rate: 5.0000e-04
# Epoch 61/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - accuracy: 0.8352 - loss: 0.4501 - val_accuracy: 0.8756 - val_loss: 0.3397 - learning_rate: 5.0000e-04
# Epoch 62/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.8345 - loss: 0.4510 - val_accuracy: 0.8765 - val_loss: 0.3415 - learning_rate: 5.0000e-04
# Epoch 63/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.8345 - loss: 0.4498 - val_accuracy: 0.8782 - val_loss: 0.3400 - learning_rate: 5.0000e-04
# Epoch 64/100
# 1265/1269 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8353 - loss: 0.4469
# Epoch 64: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.8353 - loss: 0.4469 - val_accuracy: 0.8765 - val_loss: 0.3405 - learning_rate: 5.0000e-04
# Epoch 65/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - accuracy: 0.8367 - loss: 0.4440 - val_accuracy: 0.8790 - val_loss: 0.3369 - learning_rate: 2.5000e-04
# Epoch 66/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.8361 - loss: 0.4447 - val_accuracy: 0.8780 - val_loss: 0.3361 - learning_rate: 2.5000e-04
# Epoch 67/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - accuracy: 0.8387 - loss: 0.4424 - val_accuracy: 0.8779 - val_loss: 0.3357 - learning_rate: 2.5000e-04
# Epoch 68/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - accuracy: 0.8383 - loss: 0.4406 - val_accuracy: 0.8787 - val_loss: 0.3357 - learning_rate: 2.5000e-04
# Epoch 69/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.8394 - loss: 0.4371 - val_accuracy: 0.8778 - val_loss: 0.3349 - learning_rate: 2.5000e-04
# Epoch 70/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8381 - loss: 0.4408 - val_accuracy: 0.8798 - val_loss: 0.3358 - learning_rate: 2.5000e-04
# Epoch 71/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 12s 8ms/step - accuracy: 0.8383 - loss: 0.4383 - val_accuracy: 0.8805 - val_loss: 0.3351 - learning_rate: 2.5000e-04
# Epoch 72/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.8363 - loss: 0.4416 - val_accuracy: 0.8794 - val_loss: 0.3345 - learning_rate: 2.5000e-04
# Epoch 73/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.8376 - loss: 0.4388 - val_accuracy: 0.8791 - val_loss: 0.3350 - learning_rate: 2.5000e-04
# Epoch 74/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.8384 - loss: 0.4391 - val_accuracy: 0.8778 - val_loss: 0.3338 - learning_rate: 2.5000e-04
# Epoch 75/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.8385 - loss: 0.4371 - val_accuracy: 0.8788 - val_loss: 0.3333 - learning_rate: 2.5000e-04
# Epoch 76/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.8377 - loss: 0.4410 - val_accuracy: 0.8777 - val_loss: 0.3330 - learning_rate: 2.5000e-04
# Epoch 77/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.8374 - loss: 0.4391 - val_accuracy: 0.8794 - val_loss: 0.3336 - learning_rate: 2.5000e-04
# Epoch 78/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - accuracy: 0.8390 - loss: 0.4380 - val_accuracy: 0.8793 - val_loss: 0.3331 - learning_rate: 2.5000e-04
# Epoch 79/100
# 1265/1269 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8381 - loss: 0.4387
# Epoch 79: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.8381 - loss: 0.4387 - val_accuracy: 0.8789 - val_loss: 0.3335 - learning_rate: 2.5000e-04
# Epoch 80/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.8381 - loss: 0.4405 - val_accuracy: 0.8792 - val_loss: 0.3314 - learning_rate: 1.2500e-04
# Epoch 81/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.8387 - loss: 0.4371 - val_accuracy: 0.8797 - val_loss: 0.3317 - learning_rate: 1.2500e-04
# Epoch 82/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.8410 - loss: 0.4335 - val_accuracy: 0.8790 - val_loss: 0.3309 - learning_rate: 1.2500e-04
# Epoch 83/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.8411 - loss: 0.4313 - val_accuracy: 0.8783 - val_loss: 0.3317 - learning_rate: 1.2500e-04
# Epoch 84/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.8394 - loss: 0.4355 - val_accuracy: 0.8797 - val_loss: 0.3306 - learning_rate: 1.2500e-04
# Epoch 85/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - accuracy: 0.8392 - loss: 0.4348 - val_accuracy: 0.8796 - val_loss: 0.3305 - learning_rate: 1.2500e-04
# Epoch 86/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.8402 - loss: 0.4339 - val_accuracy: 0.8801 - val_loss: 0.3306 - learning_rate: 1.2500e-04
# Epoch 87/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.8394 - loss: 0.4371 - val_accuracy: 0.8802 - val_loss: 0.3300 - learning_rate: 1.2500e-04
# Epoch 88/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.8398 - loss: 0.4332 - val_accuracy: 0.8805 - val_loss: 0.3297 - learning_rate: 1.2500e-04
# Epoch 89/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.8402 - loss: 0.4322 - val_accuracy: 0.8806 - val_loss: 0.3297 - learning_rate: 1.2500e-04
# Epoch 90/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.8404 - loss: 0.4337 - val_accuracy: 0.8806 - val_loss: 0.3295 - learning_rate: 1.2500e-04
# Epoch 91/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.8400 - loss: 0.4353 - val_accuracy: 0.8796 - val_loss: 0.3298 - learning_rate: 1.2500e-04
# Epoch 92/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.8400 - loss: 0.4347 - val_accuracy: 0.8828 - val_loss: 0.3294 - learning_rate: 1.2500e-04
# Epoch 93/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - accuracy: 0.8408 - loss: 0.4336 - val_accuracy: 0.8800 - val_loss: 0.3291 - learning_rate: 1.2500e-04
# Epoch 94/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.8419 - loss: 0.4307 - val_accuracy: 0.8813 - val_loss: 0.3294 - learning_rate: 1.2500e-04
# Epoch 95/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.8409 - loss: 0.4312 - val_accuracy: 0.8801 - val_loss: 0.3291 - learning_rate: 1.2500e-04
# Epoch 96/100
# 1262/1269 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8408 - loss: 0.4339
# Epoch 96: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.8408 - loss: 0.4339 - val_accuracy: 0.8797 - val_loss: 0.3294 - learning_rate: 1.2500e-04
# Epoch 97/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.8415 - loss: 0.4320 - val_accuracy: 0.8807 - val_loss: 0.3287 - learning_rate: 6.2500e-05
# Epoch 98/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.8407 - loss: 0.4318 - val_accuracy: 0.8807 - val_loss: 0.3279 - learning_rate: 6.2500e-05
# Epoch 99/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.8400 - loss: 0.4331 - val_accuracy: 0.8821 - val_loss: 0.3282 - learning_rate: 6.2500e-05
# Epoch 100/100
# 1269/1269 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.8395 - loss: 0.4327 - val_accuracy: 0.8821 - val_loss: 0.3279 - learning_rate: 6.2500e-05
# Restoring model weights from the end of the best epoch: 100.

# %% [markdown]
# **Evaluation**

# %%
loss, acc = model.evaluate(X_test, y_test, verbose=0)
print(f"Test Accuracy: {acc:.4f}")
# Out:
# Test Accuracy: 0.8821

# %%
y_pred_probs = model.predict(X_test)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = np.argmax(y_test, axis=1)
print("\nClassification Report:\n", classification_report(y_true, y_pred, digits=4))
# Out:
# 2537/2537 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0     0.8447    0.8167    0.8305     11245
#            1     0.8922    0.8870    0.8896     11146
#            2     0.9328    0.8813    0.9064     11613
#            3     0.8121    0.8237    0.8179     11582
#            4     0.9462    0.9010    0.9231     12426
#            5     0.8188    0.9027    0.8587     11556
#            6     0.9331    0.9589    0.9458     11611
#
#     accuracy                         0.8821     81179
#    macro avg     0.8828    0.8816    0.8817     81179
# weighted avg     0.8837    0.8821    0.8823     81179
